# %%
a = int(input())
b = int(input())
c = int(input())

if a >= b:
    if a >= c:
        if a <= b + c:
            print("Может существовать")
            min1 = b
            min2 = c
            max1 = a
    else:
        if c <= b + a:
            print("Может существовать")
            min1 = b
            min2 = a
            max1 = c
else:
    if b >= c:
        if b <= c + a:
            print("Может существовать")
            min1 = a
            min2 = c
            max1 = b
    else:
        if c <= b + a:
            print("Может существовать")
            min1 = b
            min2 = a
            max1 = c
if max1 ** 2 < min1 ** 2 + min2 ** 2:
    print("Остроугольный")
if max1 ** 2 == min1 ** 2 + min2 ** 2:
    print("Прямоугольный")
if max1 ** 2 > min1 ** 2 + min2 ** 2:
    print("Тупоугольный")
if a == b == c:
    print ("И равносторонний")
else: 
    if a == b or a == c or b == c:
        print ("И равнобедренный")
# Out:
# 3
# 3
# 5
# Может существовать
# Тупоугольный
# И равнобедренный
